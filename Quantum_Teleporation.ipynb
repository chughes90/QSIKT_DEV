# %%
#IMPORTS
import qiskit
import numpy as np
from qiskit import *
from qiskit.circuit import Gate
from qiskit.visualization import plot_histogram
from qiskit.visualization import plot_bloch_vector

# %%
qc = QuantumCircuit(3,3) #make a quantum circuit with 3 qbit and 3 classical bits
qc.h(1) #h gate on 1st qbit
qc.cx(1,2) #cx with 1st qbit a control and 2nd qbit as target
qc.cx(0,1) #cx with 0th qbit a control and 1st qbit as target
qc.h(0) #h gate on zeroth qbit
qc.measure(0,0)
qc.measure(1,1)
qc.measure(2,2)
qc.draw(output='mpl') #draw the circuit

# %%
emulator = Aer.get_backend('qasm_simulator') #GET THE SIMULATOR BACKEND (NO NOISE)

job = execute( qc, emulator, shots=100000 ) #SIMULATE THE QC DRAWN ABOVE FOR 8192 ITERATIONS

hist = job.result().get_counts() #GET THE RESULT OF THE SIMULATOR AND PRINT 
plot_histogram( hist )

# %%
#now to complete the quantum teleportation, you need a classical channel, the 0th and 1st qbits
# must be measured by observer 1 (ALICE) and the result sent to observer 2 (BOB)
#when bob receives the information, he decides to apply different quantum gates to his qbit (2nd)

# %%
qc = QuantumCircuit(3,3) #make a quantum circuit with 3 qbit and 3 classical bits
qc.h(1) #h gate on 1st qbit
qc.cx(1,2) #cx with 1st qbit a control and 2nd qbit as target
qc.cx(0,1) #cx with 0th qbit a control and 1st qbit as target
qc.h(0) #h gate on zeroth qbit
qc.measure(0,0)
qc.measure(1,1)
qc.draw(output='mpl') #draw the circuit

# %%
emulator = Aer.get_backend('qasm_simulator') #GET THE SIMULATOR BACKEND (NO NOISE)

job = execute( qc, emulator, shots=1 ) #SIMULATE THE QC DRAWN ABOVE FOR 8192 ITERATIONS

hist = job.result().get_counts() #GET THE RESULT OF THE SIMULATOR AND PRINT 
plot_histogram( hist )

# %%
# (reading from right to left as right most qbit is qbit 0)
#ALICE GOT 00, and she sends this to bob, bot must apply the identity gate to his qbit

# %%
qc = QuantumCircuit(3,3) #make a quantum circuit with 3 qbit and 3 classical bits
qc.h(1) #h gate on 1st qbit
qc.cx(1,2) #cx with 1st qbit a control and 2nd qbit as target
qc.cx(0,1) #cx with 0th qbit a control and 1st qbit as target
qc.h(0) #h gate on zeroth qbit
qc.measure(0,0)
qc.measure(1,1)
qc.draw(output='mpl') #draw the circui

emulator = Aer.get_backend('qasm_simulator') #GET THE SIMULATOR BACKEND (NO NOISE)

job = execute( qc, emulator, shots=1 ) #SIMULATE THE QC DRAWN ABOVE FOR 8192 ITERATIONS

hist = job.result().get_counts() #GET THE RESULT OF THE SIMULATOR AND PRINT 
plot_histogram( hist )

# %%
# (reading from right to left as right most qbit is qbit 0)
#ALICE GOT 01, and she sends this to bob, bot must apply the X gate to his qbit

# %%
qc = QuantumCircuit(3,3) #make a quantum circuit with 3 qbit and 3 classical bits
qc.h(1) #h gate on 1st qbit
qc.cx(1,2) #cx with 1st qbit a control and 2nd qbit as target
qc.cx(0,1) #cx with 0th qbit a control and 1st qbit as target
qc.h(0) #h gate on zeroth qbit
qc.measure(0,0)
qc.measure(1,1)
qc.draw(output='mpl') #draw the circui

emulator = Aer.get_backend('qasm_simulator') #GET THE SIMULATOR BACKEND (NO NOISE)

job = execute( qc, emulator, shots=1 ) #SIMULATE THE QC DRAWN ABOVE FOR 8192 ITERATIONS

hist = job.result().get_counts() #GET THE RESULT OF THE SIMULATOR AND PRINT 
plot_histogram( hist )

# %%
# (reading from right to left as right most qbit is qbit 0)
#ALICE GOT 10, and she sends this to bob, bob must apply the Z gate to his qbit

# %%
qc = QuantumCircuit(3,3) #make a quantum circuit with 3 qbit and 3 classical bits
qc.h(1) #h gate on 1st qbit
qc.cx(1,2) #cx with 1st qbit a control and 2nd qbit as target
qc.cx(0,1) #cx with 0th qbit a control and 1st qbit as target
qc.h(0) #h gate on zeroth qbit
qc.measure(0,0)
qc.measure(1,1)
qc.draw(output='mpl') #draw the circui

emulator = Aer.get_backend('qasm_simulator') #GET THE SIMULATOR BACKEND (NO NOISE)

job = execute( qc, emulator, shots=1 ) #SIMULATE THE QC DRAWN ABOVE FOR 8192 ITERATIONS

hist = job.result().get_counts() #GET THE RESULT OF THE SIMULATOR AND PRINT 
plot_histogram( hist )

# %%
# (reading from right to left as right most qbit is qbit 0)
#ALICE GOT 11, and she sends this to bob, bob must apply the Z gate to his qbit, then X
