# %%
#IMPORTS
import qiskit
import numpy as np
from qiskit import *
from qiskit.circuit import Gate
from qiskit.visualization import plot_histogram
from qiskit.visualization import plot_bloch_vector

# %%
#BASIC GATE IDENTITES

# %%
#make the superposition |+>
qc = QuantumCircuit(2,2) #make a quantum circuit with 2 qbit and 2 classical bits
qc.cz(0,1) #controlled z gate, 0 control qbit, 1 target qbit
qc.measure(0,0)
qc.measure(1,1)
qc.draw(output='mpl') #draw the circuit

# %%
emulator = Aer.get_backend('qasm_simulator') #GET THE SIMULATOR BACKEND (NO NOISE)

job = execute( qc, emulator, shots=100000 ) #SIMULATE THE QC DRAWN ABOVE FOR 8192 ITERATIONS

# %%
hist = job.result().get_counts() #GET THE RESULT OF THE SIMULATOR AND PRINT 
plot_histogram( hist )

# %%
#In IBM Q devices, however, the only kind of two-qubit gate that can be directly applied is the CNOT

# %%
# also a controlled-Z
qc = QuantumCircuit(2,2) #make a quantum circuit with 2 qbit and 2 classical bits
qc.h(0) 
qc.cx(0,1) #controlled x gate, 0 control qbit, 1 target qbit
qc.h(0) 
qc.measure(0,0)
qc.measure(1,1)
qc.draw(output='mpl') #draw the circuit

# %%
emulator = Aer.get_backend('qasm_simulator') #GET THE SIMULATOR BACKEND (NO NOISE)

job = execute( qc, emulator, shots=100000 ) #SIMULATE THE QC DRAWN ABOVE FOR 8192 ITERATIONS

# %%
hist = job.result().get_counts() #GET THE RESULT OF THE SIMULATOR AND PRINT 
plot_histogram( hist )

# %%
# also a controlled-Y
qc = QuantumCircuit(2,2) #make a quantum circuit with 2 qbit and 2 classical bits
qc.sdg(0) 
qc.cx(0,1) #controlled x gate, 0 control qbit, 1 target qbit
qc.s(0) 
qc.measure(0,0)
qc.measure(1,1)
qc.draw(output='mpl') #draw the circuit

# %%
emulator = Aer.get_backend('qasm_simulator') #GET THE SIMULATOR BACKEND (NO NOISE)

job = execute( qc, emulator, shots=100000 ) #SIMULATE THE QC DRAWN ABOVE FOR 8192 ITERATIONS

hist = job.result().get_counts() #GET THE RESULT OF THE SIMULATOR AND PRINT 
plot_histogram( hist )

# %%
# a controlled-H
qc = QuantumCircuit(2,2) #make a quantum circuit with 2 qbit and 2 classical bits
qc.ry(-3.14159/4,0)
qc.cx(0,1) #controlled z gate, 0 control qbit, 1 target qbit
qc.ry(3.14159/4,0)
qc.measure(0,0)
qc.measure(1,1)
qc.draw(output='mpl') #draw the circuit

# %%
emulator = Aer.get_backend('qasm_simulator') #GET THE SIMULATOR BACKEND (NO NOISE)

job = execute( qc, emulator, shots=100000 ) #SIMULATE THE QC DRAWN ABOVE FOR 8192 ITERATIONS

hist = job.result().get_counts() #GET THE RESULT OF THE SIMULATOR AND PRINT 
plot_histogram( hist )

# %%
# swap gate
qc = QuantumCircuit(2,2) #make a quantum circuit with 2 qbit and 2 classical bits
qc.h(0)
qc.cx(0,1) #controlled x gate, 0 control qbit, 1 target qbit
qc.swap(0,1)
qc.measure(0,0)
qc.measure(1,1)
qc.draw(output='mpl') #draw the circuit

# %%
emulator = Aer.get_backend('qasm_simulator') #GET THE SIMULATOR BACKEND (NO NOISE)

job = execute( qc, emulator, shots=100000 ) #SIMULATE THE QC DRAWN ABOVE FOR 8192 ITERATIONS

hist = job.result().get_counts() #GET THE RESULT OF THE SIMULATOR AND PRINT 
plot_histogram( hist )
